# %% [markdown]
# # Data Exploration of Flood Risk in Sri Lanka
#
# This notebook explores flood_dataset.csv, the dataset behind the
# Sri Lanka Flood Monitoring & Prediction System. It covers all 25 districts
# of Sri Lanka with 25,000 readings across 14,000+ locations.

# %% [markdown]
# ## Import Required Libraries

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("../data/flood_dataset.csv")
print(f"Rows: {len(df):,}   Columns: {df.shape[1]}")
df.head()
# Out:
# Rows: 25,000   Columns: 32
#   record_id     district      place_name  latitude  longitude  elevation_m  \
# 0   F100000      Kegalle        Kudagama  7.416887  81.789107           88
# 1   F100001       Matara       Kiriwatta  6.266956  81.041369           58
# 2   F100002  Trincomalee   Uduthota East  6.742164  80.927326           80
# 3   F100003     Puttalam   Mahagama East  5.922365  81.484788          111
# 4   F100004       Matara  Welimulla East  7.899872  80.826149           26
#
#    distance_to_river_m    landcover soil_type   water_supply  ...  \
# 0                339.2      Wetland     Loamy      Municipal  ...
# 1               1257.6  Agriculture      Clay      Municipal  ...
# 2               5225.3       Forest     Silty           Well  ...
# 3               2950.4        Urban     Sandy  Surface water  ...
# 4                228.3  Agriculture     Silty           Well  ...
#
#   infrastructure_score nearest_hospital_km  nearest_evac_km  flood_risk_score  \
# ...

# %% [markdown]
# ## Structure & data quality

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   record_id                       25000 non-null  str
#  1   district                        25000 non-null  str
#  2   place_name                      25000 non-null  str
#  3   latitude                        25000 non-null  float64
#  4   longitude                       25000 non-null  float64
#  5   elevation_m                     25000 non-null  int64
#  6   distance_to_river_m             25000 non-null  float64
#  7   landcover                       25000 non-null  str
#  8   soil_type                       25000 non-null  str
#  9   water_supply                    25000 non-null  str
#  10  electricity                     24211 non-null  str
#  11  road_quality                    25000 non-null  str
# ...

# %%
df.describe()
# Out:
#            latitude     longitude   elevation_m  distance_to_river_m  \
# count  25000.000000  25000.000000  25000.000000         25000.000000
# mean       7.920075     80.768514    187.514480          2013.472684
# std        1.168603      0.647936    323.405463          2007.170691
# min        5.900090     79.650121      0.000000             0.000000
# 25%        6.907247     80.211357     31.000000           582.975000
# 50%        7.923315     80.760618     68.000000          1394.200000
# 75%        8.929212     81.329265    124.000000          2783.400000
# max        9.949978     81.899993   2148.000000         16802.000000
#
#        population_density_per_km2  built_up_percent  rainfall_7d_mm  \
# count                25000.000000      25000.000000    25000.000000
# mean                   625.340320         25.222840       80.386532
# std                    504.674553         18.619808       58.434452
# min                     10.000000          1.000000        0.000000
# ...
